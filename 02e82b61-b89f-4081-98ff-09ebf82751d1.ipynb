# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Дана, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделала большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример из 3 проекта:
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# # Проект: Статистический анализ данных
#
# Вы — аналитик в популярном сервисе аренды самокатов GoFast. В вашем распоряжении находятся данные о пользователях из различных городов, а также информация о их поездках. Ваша задача — проанализировать эти данные и проверить гипотезы, которые могут способствовать росту бизнеса.
#
# Для совершения поездок по городу пользователи GoFast используют мобильное приложение. Сервис предоставляет следующие возможности:
#
# - Без подписки:
#   - Отсутствие абонентской платы.
#   - Стоимость одной минуты поездки — 8 рублей.
#   - Стоимость начала поездки — 50 рублей.
#
# - С подпиской Ultra:
#   - Абонентская плата — 199 рублей в месяц.
#   - Стоимость одной минуты поездки — 6 рублей.
#   - Начало поездки — бесплатно.
#
# Описание данных включает информацию о пользователях, их поездках и подписках.
# ### Цель исследования
#
# Я собираюсь проанализировать данные пользователей и их поездок в сервисе аренды самокатов GoFast. Моя цель — выявить закономерности в поведении пользователей и проверить гипотезы, которые помогут увеличить количество подписчиков и выручку компании.
#
# ### Ход исследования
#
# 1. **Загрузка данных**
# 2. **Предобработка данных**
# 3. **Исследовательский анализ данных**
# 4. **Объединение данных**
# 5. **Подсчёт выручки**
# 6. **Проверка гипотез**
# 7. **(Необязательное задание) Распределения**

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
from scipy import stats
from scipy.stats import binom
from scipy.stats import norm
import scipy.stats as st

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо. Модули выгружены

# %% [markdown]
# #### Шаг 1. Загрузка данных

# %%
users_df = pd.read_csv('/datasets/users_go.csv')
rides_df = pd.read_csv('/datasets/rides_go.csv')
subscriptions_df = pd.read_csv('/datasets/subscriptions_go.csv')

# %%
# Вывод первых строк каждого датафрейма
display("Первые строки датафрейма пользователей:")
display(users_df.head())

display("Первые строки датафрейма поездок:")
display(rides_df.head())

display("Первые строки датафрейма подписок:")
display(subscriptions_df.head())
# Out:
# 'Первые строки датафрейма пользователей:'
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra
# 'Первые строки датафрейма поездок:'
#    user_id     distance   duration        date
# 0        1  4409.919140  25.599769  2021-01-01
# 1        1  2617.592153  15.816871  2021-01-18
# 2        1   754.159807   6.232113  2021-04-20
# 3        1  2694.783254  18.511000  2021-08-11
# 4        1  4028.687306  26.265803  2021-08-28
# 'Первые строки датафрейма подписок:'
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0              free             8                50                 0
# ...

# %% [markdown]
# В загруженных данных содержатся три датафрейма. Датафрейм пользователей (users_df) включает информацию о 22-31-летних пользователях из разных городов, подписанных на различные типы услуг, в том числе "ultra". Датафрейм поездок (rides_df) содержит сведения о поездках, включая дистанцию, продолжительность и дату, которые совершали поездки в разные даты в 2021 году. Наконец, датафрейм подписок (subscriptions_df) описывает различные типы подписок, их стоимость и условия, где "free" и "ultra" имеют разные тарифы за минуту и стартовую цену поездки.

# %%
# Вывод общей информации о каждом датафрейме
display("Общая информация о датафрейме пользователей:")
display(users_df.info())

display("Общая информация о датафрейме поездок:")
display(rides_df.info())

display("Общая информация о датафрейме подписок:")
display(subscriptions_df.info())
# Out:
# 'Общая информация о датафрейме пользователей:'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1565 entries, 0 to 1564
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1565 non-null   int64
#  1   name               1565 non-null   object
#  2   age                1565 non-null   int64
#  3   city               1565 non-null   object
#  4   subscription_type  1565 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 61.3+ KB
# None
# 'Общая информация о датафрейме поездок:'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18068 entries, 0 to 18067
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   18068 non-null  int64
#  1   distance  18068 non-null  float64
#  2   duration  18068 non-null  float64
#  3   date      18068 non-null  object
# dtypes: float64(2), int64(1), object(1)
# ...

# %% [markdown]
# В предоставленных датафреймах содержится следующая информация. Датафрейм пользователей (`users_df`) включает 1565 записей с пятью столбцами: `user_id`, `name`, `age`, `city` и `subscription_type`. Все столбцы содержат непустые значения, а типы данных представлены целыми числами (для `user_id` и `age`) и строками (для остальных). Датафрейм поездок (`rides_df`) значительно больше, содержит 18068 записей с четырьмя столбцами: `user_id`, `distance`, `duration` и `date`. Все записи также полные, с типами данных, включающими целые и вещественные числа, а дата представлена как строка. Наконец, датафрейм подписок (`subscriptions_df`) состоит из всего двух записей с четырьмя столбцами: `subscription_type`, `minute_price`, `start_ride_price` и `subscription_fee`, все значения также непустые и представлены в основном целыми числами и строками.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Предлагаю разделять логически разные вещи:
#
#
#     - открытие данных (это может быть не тривиальный процесс)
#     - рабочий код
#
# Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок если они есть и исключит повторное выполнение кода

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Для вывода датафрейм объекта лучше использовать display(), а не print(). Так будет нагляднее

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы как нибудь прокомментировать полученные данные в разделе
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Спасибо за правки, но отсутствует промежуточный вывод. Добавь, пожалуйста

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Этот раздел сделан хорошо. Проверены основные возможные проблемы в данных.

# %% [markdown]
# #### Шаг 2. Предобработка данных

# %%
# 2.1 Приведение столбца date к типу даты
rides_df['date'] = pd.to_datetime(rides_df['date'])

# 2.2 Создание нового столбца с номером месяца
rides_df['month'] = rides_df['date'].dt.month

# %%
# 1. Проверка диапазона дат
date_range = rides_df['date'].min(), rides_df['date'].max()
print(f"Диапазон дат: {date_range[0].date()} - {date_range[1].date()}")

# 2. Анализ столбца 'duration' на наличие аномалий
# Например, можно вычислить основные статистики и выявить выбросы
duration_stats = rides_df['duration'].describe()
display("Статистика по столбцу 'duration':")
display(duration_stats)

# Поиск аномалий - например, поездки длительностью менее 1 минуты (60 секунд)
anomalies = rides_df[(rides_df['duration'] < 1)]
print(f"Количество аномальных поездок: {len(anomalies)}")
# Out:
# Диапазон дат: 2021-01-01 - 2021-12-30
# "Статистика по столбцу 'duration':"
# count    18068.000000
# mean        17.805011
# std          6.091051
# min          0.500000
# 25%         13.597563
# 50%         17.678395
# 75%         21.724800
# max         40.823963
# Name: duration, dtype: float64
# Количество аномальных поездок: 95

# %% [markdown]
# Диапазон дат: данные охватывают период с 1 января 2021 года по 30 декабря 2021 года.
#
# Статистика по столбцу duration:
#
# Количество записей: 18068
# Среднее значение: 17.81 минуты
# Стандартное отклонение: 6.09 минуты
# Минимальное значение: 0.50 минуты (30 секунд)
# 25-й процентиль: 13.60 минуты
# Медиана (50-й процентиль): 17.68 минуты
# 75-й процентиль: 21.72 минуты
# Максимальное значение: 40.82 минуты
# Количество аномальных поездок: 95 поездок имеют аномальные значения длительности, что может указывать на некорректные данные (например, поездки, длительность которых менее 1 минуты).

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Хорошо бы проверить за какой период у нас данные. Проверить столбец длительности на предмет наличия аномалий. Например, если у нас разные года то январь 2021 и январь 2022 будут под одной цифрой (1).
# </div>

# %%
# 2.3 Проверка наличия пропущенных значений и дубликатов
display("Проверка пропущенных значений в датафрейме пользователей:")
display(users_df.isnull().sum())

display("Проверка пропущенных значений в датафрейме поездок:")
display(rides_df.isnull().sum())

display("Проверка пропущенных значений в датафрейме подписок:")
display(subscriptions_df.isnull().sum())
# Out:
# 'Проверка пропущенных значений в датафрейме пользователей:'
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# dtype: int64
# 'Проверка пропущенных значений в датафрейме поездок:'
# user_id     0
# distance    0
# duration    0
# date        0
# month       0
# dtype: int64
# 'Проверка пропущенных значений в датафрейме подписок:'
# subscription_type    0
# minute_price         0
# start_ride_price     0
# subscription_fee     0
# dtype: int64

# %%
# Проверка на дубликаты
display("Проверка дубликатов в датафрейме пользователей:", users_df.duplicated().sum())
display("Проверка дубликатов в датафрейме поездок:", rides_df.duplicated().sum())
display("Проверка дубликатов в датафрейме подписок:", subscriptions_df.duplicated().sum())
# Out:
# 'Проверка дубликатов в датафрейме пользователей:'
# 31
# 'Проверка дубликатов в датафрейме поездок:'
# 0
# 'Проверка дубликатов в датафрейме подписок:'
# 0

# %%
# Удаляем дубликаты
users_df_cleaned = users_df.drop_duplicates()

# Печатаем количество дубликатов после удаления
display (f'Количество дубликатов после удаления: {users_df_cleaned.duplicated().sum()}')
# Out:
# 'Количество дубликатов после удаления: 0'

# %%
# Вывод информации о датафреймах после обработки
display("Обновленная информация о датафрейме пользователей:")
display(users_df_cleaned.head())
display(users_df_cleaned.info())
# Out:
# 'Обновленная информация о датафрейме пользователей:'
#    user_id        name  age            city subscription_type
# 0        1        Кира   22          Тюмень             ultra
# 1        2   Станислав   31            Омск             ultra
# 2        3     Алексей   20          Москва             ultra
# 3        4  Константин   26  Ростов-на-Дону             ultra
# 4        5       Адель   28            Омск             ultra
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1534 entries, 0 to 1533
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   user_id            1534 non-null   int64
#  1   name               1534 non-null   object
#  2   age                1534 non-null   int64
#  3   city               1534 non-null   object
#  4   subscription_type  1534 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 71.9+ KB
# None

# %% [markdown]
#  **Предобработка данных**
#
# 1. **Преобразование даты:**
#    Первым шагом я преобразовала столбец `date` в датафрейме поездок в формат даты, чтобы упростить дальнейший анализ, такой как выделение месяца и сортировка по дате.
#
# 2. **Создание столбца с номером месяца:**
#    На основе даты каждой поездки я добавила новый столбец `month`, содержащий номер месяца, в который была совершена поездка. Это упростит анализ данных на ежемесячном уровне.
#
# 3. **Проверка на пропущенные значения:**
#    Я проверила каждый датафрейм — пользователей, поездок и подписок — на наличие пропущенных значений. Результаты показали, что отсутствующих данных нет, что означает, что все записи полные и не требуют дополнительного заполнения.
#
# 4. **Проверка на дубликаты:**
#    Для каждого датафрейма я также провела проверку на наличие дублирующихся строк. Дубликаты обнаружены в количестве 31 общее количество строк 1565, после очистки данных дубликатов 0 общееколичество строк 1534.
#
# 5. **Просмотр обновлённых данных:**
#    Для финальной проверки я вывела первые строки датафрейма с поездками. Данные отобразились корректно и содержат все необходимые для анализа столбцы, включая дату и месяц.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Твой проект тяжело проверять, поскольку весь код написан в одной ячейке, отсутствует промежуточные выводы и т.п. Пожалуйста, воспользуйся методичкой по оформлению проекта из теоритической части

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Отсутствует обработка дубликатов. Добавь, пожалуйста

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Проверка на дубликаты - основа предобработки данных

# %% [markdown]
# #### Шаг 3. Исследовательский анализ данных

# %%
# 3.1 Частота встречаемости городов
plt.figure(figsize=(10, 6))
city_counts = users_df['city'].value_counts()
sns.barplot(x=city_counts.index, y=city_counts.values, palette='viridis')
plt.title('Частота встречаемости городов')
plt.xlabel('Город')
plt.ylabel('Количество пользователей')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличный и наглядный график 👍
#
# Здорово, когда он подписан. Так быстрее понять о чем идёт речь на нём.
#
# </div>

# %% [markdown]
# На графике видно, что больше всего пользователей сосредоточено в Пятигорске, где их количество превышает 200 человек. Екатеринбург и Ростов-на-Дону также занимают лидирующие позиции с сопоставимым числом пользователей. В то же время, такие города, как Тюмень и Москва, имеют относительно меньшее количество пользователей.
#
# Эти данные свидетельствуют о том, что наибольшая популярность сервиса GoFast наблюдается в Пятигорске и других крупных городах, тогда как Москва, несмотря на свой статус, имеет сравнительно низкий уровень использования. Эта информация может быть полезна для определения стратегий продвижения и анализа спроса в каждом из городов.

# %%
plt.figure(figsize=(8, 8))
subscription_counts = users_df['subscription_type'].value_counts()
plt.pie(subscription_counts, labels=subscription_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('pastel'))
plt.title('Соотношение пользователей с подпиской и без подписки')
plt.show()

# %% [markdown]
# На диаграмме представлено распределение пользователей по типам подписки: "ultra" и "free". Видно, что большинство пользователей (54,1%) пользуются бесплатной версией сервиса, в то время как доля пользователей с платной подпиской "ultra" составляет 45,9%. Это означает, что бесплатная версия сервиса пользуется большей популярностью среди пользователей. Однако, несмотря на меньшую долю, пользователи с платной подпиской приносят существенный вклад в выручку компании, как было показано в предыдущих анализах.
#
# Ключевые выводы:
#
# Бесплатная версия сервиса более популярна среди пользователей.
# Пользователи с платной подпиской составляют меньшую часть пользователей, но приносят больший доход.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Не посчитано соотношение категорий пользователей в процентах или в долях от целого, именно это просят в задании. Рекомендую использовать другой тип графика: круговую диаграмму, она лучше показывает соотношение частей целого.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Пользователей с подпиской немного меньше, тем не менее у компании-прокатчика есть неплохая база постоянных клиентов.

# %%
# 3.3 Возраст пользователей
plt.figure(figsize=(10, 6))
sns.histplot(users_df['age'], bins=10, kde=True, color='skyblue')
plt.title('Возраст пользователей')
plt.xlabel('Возраст')
plt.ylabel('Количество пользователей')
plt.show()

# %% [markdown]
# На гистограмме отображено распределение пользователей сервиса GoFast по возрасту.
#
# Наиболее значительная часть пользователей приходится на возрастной диапазон от 20 до 30 лет, с пиком около 25 лет. Это может указывать на то, что основную клиентскую базу сервиса составляют молодые люди. Число пользователей заметно снижается как среди подростков младше 20 лет, так и среди пользователей старше 30 лет.
#
# Эти данные могут быть полезны при планировании маркетинговых стратегий, направленных на привлечение и удержание пользователей в наиболее активной возрастной категории.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Основная часть пользователей возрастом от 22 до 28 лет. Все что меньше 15 лет и больше 40 можно считать редкими значениями.

# %%
# 3.4 Расстояние, которое пользователь преодолел за одну поездку
plt.figure(figsize=(10, 6))
sns.histplot(rides_df['distance'], bins=30, kde=True, color='lightgreen')
plt.title('Расстояние, преодолеваемое за одну поездку')
plt.xlabel('Расстояние (метры)')
plt.ylabel('Количество поездок')
plt.show()

# %% [markdown]
# Гистограмма распределения расстояний поездок показывает, что большинство поездок имеют длину около 3 километров. Распределение положительно скошено, что свидетельствует о наличии более длинных поездок. Кривая нормального распределения неплохо описывает данные, за исключением длинного правого хвоста. Отсутствие очень коротких и очень длинных поездок может быть связано с особенностями выборки данных или типа транспорта. Для более глубокого анализа рекомендуется рассчитать дополнительные статистические характеристики и сравнить данные с другими исследованиями.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Основная часть поездок занимает от 2500 до 3800 метров. Медиана 3133 метра. Поездки на расстояние более 5 км редки. Однако на гистограмме видно, что некоторая часть пользователей использует самокаты для коротких поездок - до 1500 м.

# %%
# 3.5 Продолжительность поездок
plt.figure(figsize=(10, 8))

# Гистограмма с KDE для продолжительности поездок
plt.subplot(2, 1, 1)
sns.histplot(rides_df['duration'], bins=30, kde=True, color='salmon')
plt.title('Продолжительность поездок')
plt.xlabel('Продолжительность (минуты)')
plt.ylabel('Количество поездок')

# Боксплот для продолжительности поездок
plt.subplot(2, 1, 2)
sns.boxplot(x=rides_df['duration'], color='salmon')
plt.xlabel('Продолжительность (минуты)')

plt.tight_layout()
plt.show()

# %% [markdown]
# Представлены два графика, визуализирующих распределение продолжительности поездок:
#
# Гистограмма: Позволяет оценить частоту встречаемости различных значений продолжительности поездок. На ней видно, что большинство поездок длится от 15 до 20 минут. Распределение имеет приблизительно нормальный вид, что говорит о том, что большинство поездок имеют схожую продолжительность.
# Ящик с усами: Дополнительно показывает основные характеристики распределения: медиану, квартили и выбросы. Медиана (крайняя линия внутри ящика) находится примерно на отметке 19 минут, что подтверждает данные гистограммы. Усы показывают диапазон, в который попадает большинство данных (между первым и третьим квартилем). Точки за пределами усов – это выбросы, то есть значения, значительно отличающиеся от основной массы данных.
# Выводы по графикам
#
# Средняя продолжительность поездки: Около 19 минут.
# Разброс данных: Значительная часть поездок длится от 15 до 25 минут, однако есть как более короткие, так и более длительные поездки.
# Наличие выбросов: Есть небольшое количество поездок, значительно превышающих среднюю продолжительность. Это могут быть, например, поездки в отдаленные районы или поездки с длительными остановками.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Хорошо бы графики подкрепить боксплотом

# %% [markdown]
# #### Шаг 4. Объединение данных

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#  Отсутствует проверка размерности:
#
# * размеры датасетов до объединения
# * размер результирующего датафрейма (с учетом типа объединения)

# %%
# Размеры датасетов до объединения
display("Размеры исходных датасетов:")
display(f"rides_df: {rides_df.shape}")
display(f"users_df: {users_df.shape}")
display(f"subscriptions_df: {subscriptions_df.shape}")
# Out:
# 'Размеры исходных датасетов:'
# 'rides_df: (18068, 5)'
# 'users_df: (1565, 5)'
# 'subscriptions_df: (2, 4)'

# %%
# 4.1 Объединение данных о пользователях, поездках и подписках
merged_df = rides_df.merge(users_df, on='user_id', how='inner').merge(subscriptions_df, on='subscription_type', how='inner')

# Размер результирующего датафрейма
display("\nРазмер результирующего датафрейма:")
display(f"merged_df: {merged_df.shape}")

# Проверяем результат объединения
display(merged_df.head())
# Out:
# '\nРазмер результирующего датафрейма:'
# 'merged_df: (18388, 12)'
#    user_id     distance   duration       date  month  name  age    city  \
# 0        1  4409.919140  25.599769 2021-01-01      1  Кира   22  Тюмень
# 1        1  2617.592153  15.816871 2021-01-18      1  Кира   22  Тюмень
# 2        1   754.159807   6.232113 2021-04-20      4  Кира   22  Тюмень
# 3        1  2694.783254  18.511000 2021-08-11      8  Кира   22  Тюмень
# 4        1  4028.687306  26.265803 2021-08-28      8  Кира   22  Тюмень
#
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0             ultra             6                 0               199
# 1             ultra             6                 0               199
# 2             ultra             6                 0               199
# 3             ultra             6                 0               199
# 4             ultra             6                 0               199

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №3__
#
# Хорошо бы тут дать вывод. Иначе непонятно, размерность совпадает или нет

# %%
# 4.2 Создание датафреймов для пользователей с подпиской и без подписки
users_with_subscription = merged_df[merged_df['subscription_type'] == 'ultra']
users_without_subscription = merged_df[merged_df['subscription_type'] == 'free']

# Проверяем размеры новых датафреймов
display(f"Пользователи с подпиской: {users_with_subscription.shape[0]}")
display(f"Пользователи без подписки: {users_without_subscription.shape[0]}")
# Out:
# 'Пользователи с подпиской: 6672'
# 'Пользователи без подписки: 11716'

# %%
# Вывод нескольких строк из общего датафрейма и отдельных датафреймов
print("\nПример данных общего датафрейма:")
display(merged_df.head())

print("\nПример данных для пользователей с подпиской:")
display(users_with_subscription.head())

print("\nПример данных для пользователей без подписки:")
display(users_without_subscription.head())
# Out:
# Пример данных общего датафрейма:
#    user_id     distance   duration       date  month  name  age    city  \
# 0        1  4409.919140  25.599769 2021-01-01      1  Кира   22  Тюмень
# 1        1  2617.592153  15.816871 2021-01-18      1  Кира   22  Тюмень
# 2        1   754.159807   6.232113 2021-04-20      4  Кира   22  Тюмень
# 3        1  2694.783254  18.511000 2021-08-11      8  Кира   22  Тюмень
# 4        1  4028.687306  26.265803 2021-08-28      8  Кира   22  Тюмень
#
#   subscription_type  minute_price  start_ride_price  subscription_fee
# 0             ultra             6                 0               199
# 1             ultra             6                 0               199
# 2             ultra             6                 0               199
# 3             ultra             6                 0               199
# 4             ultra             6                 0               199
# Пример данных для пользователей с подпиской:
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Целесообразно вывести несколько строк из общего и отдельных датафреймов.

# %%
# 4.3 Визуализация информации о расстоянии и времени поездок для пользователей обеих категорий
plt.figure(figsize=(14, 6))

# Визуализация расстояния
plt.subplot(1, 2, 1)
sns.boxplot(data=merged_df, x='subscription_type', y='distance', palette='pastel')
plt.title('Расстояние поездок для пользователей с и без подписки')
plt.xlabel('Тип подписки')
plt.ylabel('Расстояние (метры)')

# Визуализация времени
plt.subplot(1, 2, 2)
sns.boxplot(data=merged_df, x='subscription_type', y='duration', palette='pastel')
plt.title('Время поездок для пользователей с и без подписки')
plt.xlabel('Тип подписки')
plt.ylabel('Время (минуты)')

plt.tight_layout()
plt.show()

# %% [markdown]
# На представленных боксплотах сравнивается расстояние и время поездок для пользователей с двумя типами подписки: "ultra" и "free". Медианное значение расстояния для пользователей с подпиской "ultra" составляет 3500 метров, в то время как для пользователей с бесплатной подпиской - 2800 метров. Аналогично, медианное время поездки для пользователей "ultra" составляет 25 минут, а для пользователей "free" - 20 минут. Однако, для обеих групп характерен значительный разброс данных, что говорит о разнообразии пользовательского поведения. Особенно много выбросов наблюдается в группе пользователей с платной подпиской, что может быть связано с использованием сервиса для длительных поездок. Таким образом, пользователи с платной подпиской склонны совершать более длительные поездки, но в целом для обеих групп характерна высокая вариативность данных.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# У пользователей без подписки значительно больше коротких поездок - до 1 км и в целом максимальная дальность поездки выше, чем у платных пользователей.

# %% [markdown]
# #### Шаг 5. Подсчёт выручки

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Нет проверки на пропуски в сводной таблице перед расчетом выручки

# %%
print("Количество пропусков перед агрегацией:")
print(merged_df[['user_id', 'name', 'age', 'city', 'subscription_type', 'month', 'distance', 'duration']].isna().sum())
# Out:
# Количество пропусков перед агрегацией:
# user_id              0
# name                 0
# age                  0
# city                 0
# subscription_type    0
# month                0
# distance             0
# duration             0
# dtype: int64

# %%
# 5.1 Создание датафрейма с агрегированными данными
# Сначала округляем продолжительность поездки до следующего целого числа
rides_df['duration'] = np.ceil(rides_df['duration'])

# Создаем новый датафрейм с помесячной агрегацией
aggregated_data = (
    merged_df.groupby(['user_id', 'name', 'age', 'city', 'subscription_type', 'month'])
    .agg(
        total_distance=('distance', 'sum'),
        total_rides=('distance', 'size'),  # Считаем количество поездок
        total_duration=('duration', 'sum')
    )
    .reset_index()
)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отлично, что используешь именно np.ceil(). Грамотный шаг

# %%
# 5.2 Добавление столбца с помесячной выручкой

# Округляем total_duration после агрегации
aggregated_data['total_duration'] = np.ceil(aggregated_data['total_duration'])

# Функция для расчета выручки
def calculate_revenue(row):
    start_ride_price = 0
    if row['subscription_type'] == 'ultra':
        start_ride_price = 0  
        subscription_fee = 199  
        minute_price = 6  
    else:
        start_ride_price = 50  
        subscription_fee = 0  
        minute_price = 8  

    revenue = (start_ride_price * row['total_rides'] +
               minute_price * row['total_duration'] +
               subscription_fee)
    
    return revenue

# Применяем функцию для расчета выручки
aggregated_data['revenue'] = aggregated_data.apply(calculate_revenue, axis=1)

# Проверяем результаты
display(aggregated_data.head())
# Out:
#    user_id  name  age    city subscription_type  month  total_distance  \
# 0        1  Кира   22  Тюмень             ultra      1     7027.511294
# 1        1  Кира   22  Тюмень             ultra      4      754.159807
# 2        1  Кира   22  Тюмень             ultra      8     6723.470560
# 3        1  Кира   22  Тюмень             ultra     10     5809.911100
# 4        1  Кира   22  Тюмень             ultra     11     7003.499363
#
#    total_rides  total_duration  revenue
# 0            2            42.0    451.0
# 1            1             7.0    241.0
# 2            2            45.0    469.0
# 3            2            32.0    391.0
# 4            3            54.0    523.0

# %% [markdown]
# На шаге 5 были агрегированы данные о поездках по каждому пользователю на ежемесячной основе, рассчитывая общее расстояние, количество поездок и общее время поездок за месяц. На основе этих данных был добавлен столбец с помесячной выручкой от каждого пользователя, учитывая условия оплаты для пользователей с подпиской и без неё: для расчета использовалась сумма стоимости поездок и, при наличии подписки, ежемесячная плата. В итоге для каждого пользователя и каждого месяца отображаются данные о поездках и рассчитанная выручка.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# В итоговой таблице длительность не округлена, хотя в 17 ячейке округление выполнено. Попробуй, пожалуйста, решить этот момент самостоятельно ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Корректная реализация. Молодец)

# %% [markdown]
# #### Шаг 6. Проверка гипотез

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Отсутствует формулировка гипотез в проекте (Но/Н1). Добавь, пожалуйста по проекту
#
# H₀(нулевая гипотеза) всегда формулируется так, что иcпользовать знак равенства(=).

# %%
# Выделяем продолжительность поездок для обеих групп
duration_subscribers = merged_df[merged_df['subscription_type'] == 'ultra']['duration']
duration_non_subscribers = merged_df[merged_df['subscription_type'] == 'free']['duration']

# Выполняем t-тест
t_stat, p_value = stats.ttest_ind(duration_subscribers, duration_non_subscribers, alternative = 'greater')

# Выводим результаты
display(f'T-statistic: {t_stat}, P-value: {p_value}')
# Out:
# 'T-statistic: 12.221189269510207, P-value: 1.6261032773552045e-34'

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Не указано значение параметра alternative по всему проекту. Добавь, пожалуйста

# %% [markdown]
# **Гипотеза:**
# **Нулевая гипотеза (H0):** Средняя продолжительность поездок для пользователей с подпиской ("ultra") равна средней продолжительности поездок для пользователей без подписки ("free").
#
# **Альтернативная гипотеза (H1):** Средняя продолжительность поездок для пользователей с подпиской больше, чем для пользователей без подписки.
#
# **Подход:**
# Для проверки гипотезы используется t-тест для независимых выборок, поскольку он позволяет определить, есть ли статистически значимая разница между средней продолжительностью поездок двух независимых групп.
#
# **Интерпретация:**
#
# **P-значение (1.62e-34) < 0.05:** Значение p намного меньше уровня значимости 0.05, что указывает на статистически значимое различие между средними значениями продолжительности поездок для двух групп.
# Это означает, что вероятность получения таких различий случайно крайне мала, и мы можем с высокой уверенностью отвергнуть нулевую гипотезу.
#
# **Вывод:**
# На основании результатов t-теста мы отвергаем нулевую гипотезу и принимаем альтернативную гипотезу. Это позволяет сделать вывод, что пользователи с подпиской действительно проводят больше времени в поездках по сравнению с пользователями без подписки.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Верная интерпретация нулевой и альтернативной гипотез
# </div>

# %%
# Выделяем расстояние для пользователей с подпиской
distance_subscribers = merged_df[merged_df['subscription_type'] == 'ultra']['distance']

# Выполняем односторонний t-тест
t_stat_distance, p_value_distance = stats.ttest_1samp(distance_subscribers, 3130)

# Проверяем на одностороннее p-значение
p_value_distance_one_tailed = p_value_distance / 2

# Выводим результаты
print(f'T-statistic: {t_stat_distance}, P-value (one-tailed): {p_value_distance_one_tailed}')
# Out:
# T-statistic: -1.4219247313062973, P-value (one-tailed): 0.07754742644919703

# %% [markdown]
# **Гипотеза:**
#
# **Нулевая гипотеза (H0):** Среднее расстояние поездок пользователей с подпиской "ultra" равно или больше 3130 метров.
# **Альтернативная гипотеза (H1):** Среднее расстояние поездок пользователей с подпиской "ultra" меньше 3130 метров.
# **Подход:** Мы выполняем односторонний t-тест для проверки, является ли среднее расстояние, проезжаемое пользователями с подпиской, статистически меньше 3130 метров.
#
# **Интерпретация результатов t-теста:**
#
# **P-value (0.0804) > α (0.05):** Полученное p-значение больше выбранного уровня значимости (5%), что означает, что у нас нет достаточных статистических оснований для отклонения нулевой гипотезы.
#
# **Вывод:** На основе имеющихся данных мы не можем заключить, что среднее расстояние поездок для пользователей с подпиской "ultra" статистически значимо меньше 3130 метров. Таким образом, результаты не поддерживают гипотезу о том, что среднее расстояние, которое проезжают подписчики за одну поездку, не превышает 3130 метров.
#
# **Ответ на вопрос:**
# Нет, по результатам t-теста мы не можем утверждать, что среднее расстояние поездок для пользователей с подпиской меньше или равно 3130 метров.

# %%
# Отбираем выручку для подписчиков и пользователей без подписки
revenue_subscribers = aggregated_data[aggregated_data['subscription_type'] == 'ultra']['revenue']
revenue_non_subscribers = aggregated_data[aggregated_data['subscription_type'] == 'free']['revenue']

# Выполняем t-тест для независимых выборок
t_stat, p_value = st.ttest_ind(revenue_subscribers, revenue_non_subscribers, alternative='greater')

# Выводим результаты
print("T-статистика:", t_stat)
print("P-значение:", p_value)
# Out:
# T-статистика: 11.867245165976717
# P-значение: 1.3600256840012913e-32

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
#
# ---
#
# `Нужно ли группировать данные, которые мы подаем в стат.тест?`
#
# Нет, в функции st.ttest_ind нет необходимости группировать данные в отдельные группы. Функция сама принимает два набора данных (две выборки) и выполняет статистический тест на их независимость.
#
# Однако, перед использованием функции st.ttest_ind, важно убедиться, что данные для сравнения у вас уже разделены на две выборки в соответствии с вашими группами или условиями. Например, если у тебя есть данные о результате некоторого эксперимента для двух групп участников (например, контрольная группа и экспериментальная группа), то тебе нужно разделить данные на две выборки, каждая из которых представляет соответствующую группу.
#
# `Вот пример кода, который иллюстрирует использование st.ttest_ind для сравнения двух выборок:`
#
# import scipy.stats as st
#
# **Предположим, у нас есть две выборки data1 и data2**
#
# **Выполняем t-тест для независимых выборок**
#
# t_statistic, p_value = st.ttest_ind(data1, data2)
#
# **Выводим результаты**
#
# print("t-статистика:", t_statistic)
#
# print("p-значение:", p_value)
#
#
# В этом примере data1 и data2 - это две выборки, которые вы хотите сравнить. Функция st.ttest_ind возвращает значение t-статистики и p-значение для проверки гипотезы о равенстве средних значений в двух выборках.
#
# Таким образом, нет необходимости группировать данные перед использованием функции st.ttest_ind, но важно правильно представить данные в виде двух выборок для сравнения.
#
# ---
#
# Т.е. не нужно группировать данные

# %% [markdown]
# **Гипотеза**
# **Нулевая гипотеза (H0):** Средняя помесячная выручка от пользователей с подпиской ("ultra") не превышает выручку от пользователей без подписки ("free").
#
# **Альтернативная гипотеза (H1):** Средняя помесячная выручка от пользователей с подпиской ("ultra") больше, чем от пользователей без подписки ("free").
#
# **Интерпретация результатов**
#
# **T-статистика:** 11.87
#
# **P-значение:** 1.36e-32
#
# **Вывод:**
# Так как p-значение (1.36e-32) значительно меньше уровня значимости 0.05, мы отвергаем нулевую гипотезу. Это означает, что существует статистически значимое различие в выручке между пользователями с подпиской и без подписки.
#
# **Заключение**
# Результаты теста позволяют утверждать, что помесячная выручка от пользователей с подпиской действительно выше, чем от пользователей без подписки.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №3__
#
# Методологически проверка гипотез проведена верно и наглядный вывод результатов

# %%
# Например, если у нас есть данные в виде двух столбцов: 'pre_update' и 'post_update'
pre_update = ...  # количество обращений до обновления
post_update = ...  # количество обращений после обновления

# Выполняем t-тест для зависимых выборок
t_stat_support, p_value_support = stats.ttest_rel(pre_update, post_update)

# Выводим результаты
print(f'T-statistic: {t_stat_support}, P-value: {p_value_support}')
# Out:
# /opt/conda/lib/python3.9/site-packages/scipy/stats/_stats_py.py:110: RuntimeWarning: The input array could not be properly checked for nan values. nan values will be ignored.
#   warnings.warn("The input array could not be properly "
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_48/2362624972.py in <module>
#       4
#       5 # Выполняем t-тест для зависимых выборок
# ----> 6 t_stat_support, p_value_support = stats.ttest_rel(pre_update, post_update)
#       7
#       8 # Выводим результаты
#
# /opt/conda/lib/python3.9/site-packages/scipy/stats/_stats_py.py in ttest_rel(a, b, axis, nan_policy, alternative)
#    6901     df = n - 1
#    6902
# -> 6903     d = (a - b).astype(np.float64)
#    6904     v = _var(d, axis, ddof=1)
#    6905     dm = np.mean(d, axis)
#
# TypeError: unsupported operand type(s) for -: 'ellipsis' and 'ellipsis'

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Для решения потребуется тест на равенство средних для зависимых выборок, до и после изменений.>

# %% [markdown]
# **Нулевая гипотеза (H0):** Среднее количество обращений в техподдержку до обновления равно или превышает среднее количество обращений после обновления серверов.
# **Альтернативная гипотеза (H1):** Среднее количество обращений в техподдержку после обновления серверов меньше, чем до обновления.
#
# **Подход:** Для этой ситуации мы можем использовать тест на разность средних (t-тест для зависимых выборок), поскольку мы сравниваем количество обращений до и после обновления для одних и тех же пользователей.
#
# **Вывод:** Если p-значение меньше 0.05, мы отвергаем нулевую гипотезу и можем утверждать, что количество обращений в техподдержку снизилось после обновления.

# %% [markdown]
# #### Шаг 7. Распределения

# %%
# Заданные параметры
p = 0.1  # Вероятность продления подписки
target = 100  # Целевое количество продлений
alpha = 0.05  # Уровень значимости

# Ищем минимальное n
n = 1
while True:
    # Вычисляем вероятность P(X < 100) для биномиального распределения
    prob = binom.cdf(target - 1, n, p)
    if prob < alpha:
        break
    n += 1

# Построение графика распределения
x = np.arange(0, n+1)
pmf = binom.pmf(x, n, p)

plt.figure(figsize=(12, 6))
plt.bar(x, pmf, color='skyblue')
plt.title(f'Биномиальное распределение (n={n}, p={p})')
plt.xlabel('Количество продлений подписки')
plt.ylabel('Вероятность')
plt.axvline(x=target, color='red', linestyle='--', label='Цель: 100 продлений')
plt.legend()
plt.grid()
plt.show()

n  # Минимальное количество промокодов

# %% [markdown]
# Для того чтобы вероятность того, что менее 100 пользователей продлят подписку, была примерно 5%, необходимо разослать как минимум 1161 промокодов.

# %%
# Заданные параметры
n = 1_000_000  # Количество уведомлений
p = 0.4  # Вероятность открытия уведомления
mu = n * p  # Среднее
sigma = np.sqrt(n * p * (1 - p))  # Стандартное отклонение

# Оценка вероятности P(X <= 399500)
x = 399_500
z = (x - mu) / sigma  # Стандартное нормальное значение
prob = norm.cdf(z)  # Вероятность

# Построение графика нормального распределения
x_values = np.linspace(mu - 4*sigma, mu + 4*sigma, 1000)
y_values = norm.pdf(x_values, mu, sigma)

plt.figure(figsize=(12, 6))
plt.plot(x_values, y_values, color='skyblue', label='Нормальное распределение')
plt.fill_between(x_values, y_values, where=(x_values <= x), color='lightcoral', alpha=0.5, label='P(X ≤ 399500)')
plt.axvline(x=x, color='red', linestyle='--', label='399500 открытий')
plt.title('Нормальная аппроксимация биномиального распределения')
plt.xlabel('Количество открытий уведомлений')
plt.ylabel('Плотность вероятности')
plt.legend()
plt.grid()
plt.show()

prob  # Вероятность

# %% [markdown]
# Вероятность того, что уведомление откроют не более 399,5 тыс. пользователей, составляет приблизительно
# 𝑝, где 𝑝 — это 0.15371708296369768, полученное из нормальной аппроксимации

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Корректная реализация. Молодец!)

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №2__
#
# Итоговый вывод завершает твое исследование. А его нету...В идеале добавить рекомендации бизнесу
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №3__
#
# Отличная работа, но к сожалению, отсутствует summary по проекту. Добавь, пожалуйста

# %% [markdown]
# ### Общий вывод
#
# Анализ данных сервиса GoFast показал, что пользователи без подписки составляют большую часть клиентской базы, однако пользователи с подпиской «Ultra» приносят компании более высокий доход за счет бесплатного старта поездок и сниженной стоимости минуты. Большинство пользователей сосредоточено в Пятигорске, Екатеринбурге и Ростове-на-Дону, что указывает на их большую вовлеченность в регионах по сравнению с Москвой. Основная аудитория сервиса — молодые люди в возрасте 20-30 лет, а характерный диапазон поездок по длительности составляет 15-20 минут.
#
# Также выявлено, что пользователи с подпиской «Ultra» проводят больше времени в поездках и чаще совершают более длительные поездки по сравнению с теми, кто пользуется бесплатной версией. В то же время статистически значимых оснований утверждать, что средняя длина поездок пользователей с подпиской существенно отличается, нет. Однако ежемесячная выручка от подписчиков выше, что подтверждает финансовую выгоду платной подписки для компании.
#
# **Бизнес-идеи для роста компании**
#
# 1. **Развитие программ лояльности и дополнительных бонусов для подписчиков**: Для увеличения числа подписок на тариф «Ultra» можно внедрить бонусные программы для пользователей, например, бесплатные минуты при достижении определенного объема поездок. Это привлечет активных пользователей и повысит средний доход.
#
# 2. **Сегментированные маркетинговые кампании**: Использовать данные по возрасту и географии, чтобы фокусироваться на наиболее активных группах в Пятигорске и других лидирующих городах, а также стимулировать рост в Москве. Кампании могут включать специальные предложения для молодежи (18-30 лет), что увеличит привлечение новой аудитории.
#
# 3. **Динамическое ценообразование и специальные акции**: Предлагать временные скидки на подписку и уменьшать стоимость старта поездок в определенные часы. Динамическое ценообразование может стимулировать спрос в период низкой активности и повысить общую загрузку сервиса.
#
# 4. **Оптимизация качества обслуживания и снижение обращений в техподдержку**: Учитывая результаты анализа, можно ввести регулярные обновления приложений и серверов, а также анализировать причины обращения в поддержку, что поможет уменьшить количество обращений и повысит удовлетворенность клиентов.
#
# 5. **Анализ предпочтений пользователей и кастомизация предложений**: На основе данных о длительности и расстоянии поездок можно предлагать пользователям персонализированные рекомендации по маршрутам и выгодные тарифы. Это повысит уровень удержания пользователей и создаст дополнительные источники дохода через индивидуальный подход.
#
# Эти идеи помогут компании увеличить подписную базу, улучшить пользовательский опыт и повысить доход, оптимизируя существующие предложения и увеличивая клиентскую лояльность.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №4__
#
# Итоговый вывод завершает твое исследование. Представлены основные результаты полученные в ходе анализа, но самое главное - даны рекомендации заказчику. Это важное качество для аналитика. Развивай его и дальше
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №2 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Вводная часть
#
# 2) Проверка на дубликаты
#
# 3) Соотношение категорий пользователей в процентах или в долях от целого
#
# 4) Проверка  датафреймов до/после работы с ними
#
# 5) Округление
#
# 6) Гипотезы
#
# 7) После каждого раздела / графика (или серии тестов) писать вывод по полученным данным с учетом поставленной бизнес задачи
#
# 8) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №3 </b>
#
#
#
# Отличая работа, осталось поправить один момент:
#
# ---
#
# Нужно поправить:
#
# 1) Финальный вывод
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №4__
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличный метариал по статистике.
#
# * Курс "Вероятность и статистика" | Глеб Михайлов (free): https://www.youtube.com/playlist?list=PLQJ7ptkRY-xbHLLI66KdscKp_FJt0FsIi
#
# * Методы обнаружения выбросов: https://youtu.be/TOK7Kq7x0yc
#
#
# </div>
